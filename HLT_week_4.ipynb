# %% [markdown]
# Practical

# %% [markdown]
# Q1 How many rows and columns are there in your file?, shown below

# %%
import numpy as np

# %%
import pandas as pd

holiday_data= pd.read_csv("Destination.csv")

holiday_data.shape
# Out:
# (15, 10)

# %% [markdown]
# Answer to Q1) The Destination.csv file has 15 rows and 5 columns

# %% [markdown]
# Q2.Print row 3-8 ( using iloc/loc), shown below

# %%
import pandas as pd

holiday_data= pd.read_csv("Destination.csv")

print(holiday_data.iloc[2:8])

#since index value starts from zero, then the 3rd row of the Destination.csv data has index value 2, and the 8th row of data has index value of 7.
# Out:
#   Holiday destinations  feedback score Average hotel star rating   \
# 2               Brazil             6.0                  2/5 stars
# 3             Bulgaria             7.0                  4/5 stars
# 4               Canada             8.0                  5/5 stars
# 5               Cyprus            10.0                  5/5 stars
# 6              Denmark             8.0                  4/5 stars
# 7             Ethiopia            10.0                  5/5 stars
#
#    Number of all incluseive hotels           Most visited city
# 2                               200                  Brazillia
# 3                               100   Capital city of Bulgaria
# 4                               600                    Toronto
# 5                                20     Capital city of Cyprus
# 6                                34    Capital City of Denmark
# 7                                50  Capital City of Ethiopia

# %%
#using loc to extract rows 3 to 8 from Destination.csv file

import pandas as pd
holiday_data= pd.read_csv("Destination.csv", index_col="Holiday destinations")

print(holiday_data.loc[["Brazil", "Bulgaria", "Canada", "Cyprus", "Denmark", "Ethiopia"]])
# Out:
#                       feedback score Average hotel star rating   \
# Holiday destinations
# Brazil                           6.0                  2/5 stars
# Bulgaria                         7.0                  4/5 stars
# Canada                           8.0                  5/5 stars
# Cyprus                          10.0                  5/5 stars
# Denmark                          8.0                  4/5 stars
# Ethiopia                        10.0                  5/5 stars
#
#                       Number of all inclusive hotels   \
# Holiday destinations
# Brazil                                            200
# Bulgaria                                          100
# Canada                                             30
# Cyprus                                             20
# Denmark                                            34
# Ethiopia                                           50
#
#                               Most visited city  Unnamed: 5  Unnamed: 6  \
# ...

# %% [markdown]
# Q3.Find the mean number of all-inclusive hotels across all destinations, shown below

# %%
import pandas as pd

holiday_data=pd.read_csv("Destination.csv")

holiday_data["feedback score"].mean()

holiday_data["Number of all inclusive hotels"].mean()

# not sure why there is an error when running the statement holiday_data["Number of all inclusive hotels"].mean(), ask tutor.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\aliah\OneDrive\Documents\tech_talent_data_academy\venv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\Users\aliah\OneDrive\Documents\tech_talent_data_academy\venv\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\aliah\OneDrive\Documents\tech_talent_data_academy\venv\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Number of all inclusive hotels'
# ...

# %% [markdown]
# Q4.Find the lowest scoring destination, shown below:

# %%
min_score= np.min(holiday_data["feedback score"])

print(min_score)

holiday_data= pd.read_csv("Destination.csv")

myfilter = holiday_data["feedback score"] == min_score



lowest_dest_score = holiday_data[myfilter]
lowest_dest_score.head()
# Out:
# 1.0
#    Holiday destinations  feedback score Average hotel star rating   \
# 12             Pakistan             1.0                  2/5 stars
#
#     Number of all inclusive hotels  Most visited city  Unnamed: 5  Unnamed: 6  \
# 12                               47         Islamabad         NaN         NaN
#
#     Unnamed: 7  Unnamed: 8  Unnamed: 9
# 12         NaN         NaN         NaN

# %% [markdown]
# The above result, shows that Pakistan had the lowest feedback score

# %% [markdown]
# Q5.Find the highest scoring destination, shown below

# %%
max_score=np.max(holiday_data["feedback score"])

print(max_score)


holiday_data= pd.read_csv("Destination.csv")

myfilter = holiday_data["feedback score"] == max_score



max_dest_score = holiday_data[myfilter]
max_dest_score.head()
# The highest scoring
# Out:
# 10.0
#   Holiday destinations  feedback score Average hotel star rating   \
# 5               Cyprus            10.0                  5/5 stars
# 7             Ethiopia            10.0                  5/5 stars
#
#    Number of all inclusive hotels           Most visited city  Unnamed: 5  \
# 5                               20     Capital city of Cyprus         NaN
# 7                               50  Capital City of Ethiopia          NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9
# 5         NaN         NaN         NaN         NaN
# 7         NaN         NaN         NaN        60.0

# %% [markdown]
# the above output result shows that Cyprus and Ethiopia had the highest feed back score

# %% [markdown]
# Q6.Find all the destinations where there are more than 9 all-inclusive hotels, shown below

# %%
holiday_data= pd.read_csv("Destination.csv")

myfilter = holiday_data["Num_inclusive_hotels"] > 9



output1 = holiday_data[myfilter]
output1.head(15)
# Out:
#    Holiday destinations  feedback score Average hotel star rating   \
# 1             Australia             9.0                  5/5 stars
# 2                Brazil             6.0                  2/5 stars
# 3              Bulgaria             7.0                  4/5 stars
# 4                Canada             8.0                  5/5 stars
# 5                Cyprus            10.0                  5/5 stars
# 6               Denmark             8.0                  4/5 stars
# 7              Ethiopia            10.0                  5/5 stars
# 8               Finland             7.0                  3/5 stars
# 10             Malaysia             7.5                  3/5 stars
# 11          New Zealand             9.0                  5/5 stars
# 13             Portugal             6.0                  4/5 stars
# 14               Turkey             5.0                  3/5 stars
#
#     Num_inclusive_hotels            Most visited city  Unnamed: 5  Unnamed: 6  \
# ...

# %% [markdown]
# The destinations that have more than 9 inclusive hoteks are listed above

# %% [markdown]
# Q7. Filter the data by score above 8, shown below:

# %%
myfilter1 = holiday_data["feedback score"] > 8

output2 = holiday_data[myfilter1]
output2.head(15)
# Out:
#    Holiday destinations  feedback score Average hotel star rating   \
# 1             Australia             9.0                  5/5 stars
# 5                Cyprus            10.0                  5/5 stars
# 7              Ethiopia            10.0                  5/5 stars
# 9            Madagascar             9.0                  5/5 stars
# 11          New Zealand             9.0                  5/5 stars
#
#     Num_inclusive_hotels            Most visited city  Unnamed: 5  Unnamed: 6  \
# 1                    500                       Queens         NaN         NaN
# 5                     20       Capital city of Cyprus         NaN         NaN
# 7                     50    Capital City of Ethiopia          NaN         NaN
# 9                      7   Capital city of Madagascar         NaN         NaN
# 11                    58  Capital city of New Zealand         NaN         NaN
#
#     Unnamed: 7  Unnamed: 8  Unnamed: 9
# 1          NaN         NaN         NaN
# ...

# %% [markdown]
# Q8.Filter the data score below 2 ( I need to know if these destinations should be removed or there is a problem), shown below

# %%
myfilter2 = holiday_data["feedback score"] < 2 

output3 = holiday_data[myfilter2]
output3.head(15)
# Out:
#    Holiday destinations  feedback score Average hotel star rating   \
# 12             Pakistan             1.0                  2/5 stars
#
#     Num_inclusive_hotels Most visited city  Unnamed: 5  Unnamed: 6  \
# 12                     8         Islamabad         NaN         NaN
#
#     Unnamed: 7  Unnamed: 8  Unnamed: 9
# 12         NaN         NaN         NaN

# %% [markdown]
# Q1, Extension in page 39,
#
# Q1. Is there a correlation between number of all-inclusive hotels and score?, shown below

# %%
import matplotlib.pyplot as plt
holiday_data.plot.scatter(x='Num_inclusive_hotels', y='feedback score' )
# Out:
# <AxesSubplot:xlabel='Num_inclusive_hotels', ylabel='feedback score'>

# %% [markdown]
# Answer to Q1 od Extension task:
#
# From the scatter plot above where it has Num_inclusive_hotels and feedback score on the x and y axis, we cannot see any correlation between number of all inclusive hotels and feedback score, because most of the destinations that have a high or low feedback score all of them have relativeky low number of inclusive hotels.

# %% [markdown]
# Q2 of extension, shown below

# %%
feedback_score = np.max(holiday_data["feedback score"])
myfilter4 = holiday_data["feedback score"]==feedback_score

destinations = holiday_data[myfilter4]

destinations.shape

destinations.head(10)
# Out:
#   Holiday destinations  feedback score Average hotel star rating   \
# 5               Cyprus            10.0                  5/5 stars
# 7             Ethiopia            10.0                  5/5 stars
#
#    Num_inclusive_hotels          Most visited city  Unnamed: 5  Unnamed: 6  \
# 5                    20     Capital city of Cyprus         NaN         NaN
# 7                    50  Capital City of Ethiopia          NaN         NaN
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9
# 5         NaN         NaN         NaN
# 7         NaN         NaN        60.0

# %%
import matplotlib.pyplot as plt
fig= plt.figure(figsize=(7,5))

feedback_score = np.max(holiday_data["feedback score"])
myfilter4 = holiday_data["feedback score"]==feedback_score

destinations1 = ["Cyprus", "Ethiopia"]
positions = [0, 1]

plt.bar(positions, feedback_score, width=0.1)
plt.xticks(positions, destinations1)

plt.show()
