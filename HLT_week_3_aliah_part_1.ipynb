# %% [markdown]
# Home learning Task 1 for week 3, shown below:

# %%
num = [3,45,83,21]
my_file= open("Numbers.txt", "w")
for i in range(len(num)):
   my_file.write(str(num[i]))
   my_file.write("\n")

my_file.close()

# Now using reading from a file "r" 
with open("Numbers.txt", "r") as myfile:
   data = myfile.read().replace("\n", ",")

myfile.close()

print(data)

# Now using Appending to a file "a" 
my_file=open("Numbers.txt", "a")

my_file.write("How many numbers are listed above?")

my_file.close()
# Out:
# 3,45,83,21,

# %% [markdown]
# HLT: Task 2 of week 3 data academy, shown below

# %%
# Creating a function named mark_grade
def mark_grade():
    mark_percent = float(input("Please enter your percentage mark of your maths exam"))
    

    if 0<=mark_percent and mark_percent<30:
        output = print("The grade for you maths exam is an F")
    elif mark_percent>=30 and mark_percent<40:
        output = print("The grade for you maths exam is an E")
    elif mark_percent>=40 and mark_percent<50:
        output = print("The grade for you maths exam is a D")
    elif mark_percent>=50 and mark_percent<60:
        output= print("The grade for you maths exam is a C")
    elif mark_percent>=60 and mark_percent<70:
        output= print("The grade for you maths exam is a B")
    elif mark_percent>=70 and mark_percent<80:
         output= print("The grade for you maths exam is an A")
    else: 
        output= print("The grade for you maths exam is a Distinction")

    return output 

# calling on function mark_grade
grade = mark_grade()
# Out:
# The grade for you maths exam is an F

# %% [markdown]
# Extension to task 2 of HLT week 3

# %%
grade=mark_grade()
def mark_grade1():
    mark_percent = float(input("Please enter your percentage mark of your maths exam"))
    target_grade=float(input("Please enter your target grade"))
    print(target_grade)
    print(mark_percent)

    if 0<=mark_percent and mark_percent<30:
        output = print("The grade for you maths exam is an F")
        if target_grade>mark_percent:
           output1 = print("You have achieved a grade below your target grade")
        elif target_grade==mark_percent:
            output1 = print("You have achieved a grade equal to your target grade")
        else:
            output1 = print("You have achieved a grade above your target grade")

    elif mark_percent>=30 and mark_percent<40:
        output = print("The grade for you maths exam is an E")
        if target_grade>mark_percent:
           output1 = print("You have achieved a grade below your target grade")
        elif target_grade==mark_percent:
             output1 = print("You have achieved a grade equal to your target grade")
        else:
            output1 = print("You have achieved a grade above your target grade")

    elif mark_percent>=40 and mark_percent<50:
        output = print("The grade for you maths exam is a D")
        if target_grade>mark_percent:
           output1 = print("You have achieved a grade below your target grade")
        elif target_grade==mark_percent:
             output1 = print("You have achieved a grade equal to your target grade")
        else:
             output1 = print("You have achieved a grade above your target grade")

    elif mark_percent>=50 and mark_percent<60:
        output= print("The grade for you maths exam is a C")
        if target_grade>mark_percent:
            output1 = print("You have achieved a grade below your target grade")
        elif target_grade==mark_percent:
             output1 = print("You have achieved a grade equal to your target grade")
        else:
            output1 = print("You have achieved a grade above your target grade")

    elif mark_percent>=60 and mark_percent<70:
        output= print("The grade for you maths exam is a B.")
        if target_grade > mark_percent:
           output1 = print("You have achieved a grade below your target grade.")
        elif target_grade==mark_percent:
           output1 = print("You have achieved a grade equal to your target grade.")
        else:
           output1 = print("You have achieved a grade above your target grade.")

    elif mark_percent>=70 and mark_percent<80:
        output= print("The grade for you maths exam is an A.")
        if target_grade>mark_percent:
          output1 = print("You have achieved a grade below your target grade.")
        elif target_grade==mark_percent:
          output1 = print("You have achieved a grade equal to your target grade.")
        else:
          output1 = print("You have achieved a grade above your target grade.")

    else: 
        output= print("The grade for you maths exam is a Distinction.")
        if target_grade>mark_percent:
           output1 = print("You have achieved a grade below your target grade.")
        elif target_grade==mark_percent:
           output1 = print("You have achieved a grade equal to your target grade.")
        else:
           output1 = print("You have achieved a grade above your target grade.")

        return output1
    return output 
         

# calling on function mark_grade
grade = mark_grade1()
# Out:
# 80.0
# 67.0
# The grade for you maths exam is a B.
# You have achieved a grade below your target grade.

# %%
grade=mark_grade()

def mark_grade2():
    mark_percent = float(input("Please enter the percentage mark of your maths exam"))
    target_grade=input("Please enter your target grade, i.e. Please enter anyone of the following: Distinction, A, B, C, D, E or F")

    
    if 0<=mark_percent and mark_percent<30:
        output = print("The grade for you maths exam is an F")
        if target_grade=="Distinction" or target_grade=="A" or target_grade=="B" or target_grade=="C" or target_grade=="D" or target_grade=="E":
            output1 = print("Your target grade is", target_grade,"and you have achieved a grade below your target grade")
        else:
            output1 = print("Your target grade is", target_grade,"and you have achieved a grade equal to your target grade")
        
    elif mark_percent>=30 and mark_percent<40:
        output = print("The grade for you maths exam is an E")
        if target_grade=="Distinction" or target_grade=="A" or target_grade=="B" or target_grade=="C" or target_grade=="D":
           output1 = print("Your target grade is", target_grade,"and you have achieved a grade below your target grade")
        elif target_grade=="E":
             output1 = print("Your target grade is", target_grade,"and you have achieved a grade equal to your target grade")
        else:
            output1 = print("Your target grade is", target_grade," and you have achieved a grade above your target grade")

    elif mark_percent>=40 and mark_percent<50:
        output = print("The grade for you maths exam is a D")
        if target_grade=="Distinction" or target_grade=="A" or target_grade=="B" or target_grade=="C":
           output1 = print("Your target grade is", target_grade,"and you have achieved a grade below your target grade")
        elif target_grade=="D":
             output1 = print("Your target grade is", target_grade,"and you  have achieved a grade equal to your target grade")
        else:
             output1 = print("Your target grade is", target_grade,"and you have achieved a grade above your target grade")

    elif mark_percent>=50 and mark_percent<60:
        output= print("The grade for you maths exam is a C")
        if target_grade=="Distinction" or target_grade=="A" or target_grade=="B":
            output1 = print("Your target grade is", target_grade,"and you have achieved a grade below your target grade")
        elif target_grade=="C":
             output1 = print("Your target grade is", target_grade,"and you have achieved a grade equal to your target grade")
        else:
            output1 = print("Your target grade is", target_grade,"and you have achieved a grade above your target grade")

    elif mark_percent>=60 and mark_percent<70:
        output= print("The grade for you maths exam is a B.")
        if target_grade=="Distinction" or target_grade=="A":
           output1 = print("Your target grade is", target_grade,"and you have achieved a grade below your target grade.")
        elif target_grade=="B":
           output1 = print("Your target grade is", target_grade,"and you have achieved a grade equal to your target grade.")
        else:
           output1 = print("Your target grade is", target_grade,"and you have achieved a grade above your target grade.")

    elif mark_percent>=70 and mark_percent<80:
        output= print("The grade for you maths exam is an A.")
        if target_grade=="Distinction":
          output1 = print("Your target grade is", target_grade,"and you have achieved a grade below your target grade.")
        elif target_grade=="A":
          output1 = print("Your target grade is", target_grade,"and you have achieved a grade equal to your target grade.")
        else:
          output1 = print("Your target grade is", target_grade,"and you have achieved a grade above your target grade.")

    else: 
        output= print("The grade for you maths exam is a Distinction.")
        if target_grade =="Distinction":
           output1 = print("Your target grade is", target_grade,"and you have achieved a grade equal to your target grade.")
        else:
           output1 = print("Your target grade is", target_grade,"and you have achieved a grade above your target grade.")

        return output1
    return output 


grade2 = mark_grade2()
# Out:
# The grade for you maths exam is a D
# Your target grade is B and you have achieved a grade below your target grade

# %%
grade=mark_grade()
# Out:
# The grade for you maths exam is a C

# %%
def mark_grade3():
    grade_1 = input("Please enter the grade of your maths exam")
    target_grade=input("Please enter your target grade, i.e. Please enter anyone of the following: Distinction, A, B, C, D, E or F")

    
    if target_grade>"grade_1":
            output1 = print("Your target grade is", target_grade,"and you have achieved a grade below your target grade")
    elif target_grade=="grade_1":
            output1 = print("Your target grade is", target_grade,"and you have achieved a grade equal to your target grade")
    elif grade_1 == "Distinction":
         
         output1 = print("Your target grade is", target_grade,"and you have achieved a grade equal to your target grade")
    else:
        output1 = print("Your target grade is", target_grade,"and you have achieved a grade above your target grade")

    return output1 

target=mark_grade3()
# Out:
# Your target grade is Distinction and you have achieved a grade equal to your target grade
